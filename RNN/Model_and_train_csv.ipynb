# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from face_recognition) (1.22.4)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.9/dist-packages (from face_recognition) (8.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from face_recognition) (8.4.0)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.9/dist-packages (from face_recognition) (19.24.0)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 11.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566184 sha256=e4f8075321230db002fd4b25b9ec1239ebbd0d5309a728b6b643d6748d656bf8
#   Stored in directory: /root/.cache/pip/wheels/22/a8/60/4a2aeb763d63f50190f4c4e07069a22245347eeafdb3a67551
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face_recognition
# Successfully installed face-recognition-models-0.3.0 face_recognition-1.3.0

# %%
import csv
import json

# Load the JSON data
with open('metadata.json') as f:
    data = json.load(f)

# Write the data to a CSV file
with open('data.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    for filename, metadata in data.items():
        writer.writerow([filename, metadata['label']])

# %%
#This code is to check if the video is corrupted or not..
#If the video is corrupted delete the video.
import glob
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
#Check if the file is corrupted or not
def validate_video(vid_path,train_transforms):
      transform = train_transforms
      count = 20
      video_path = vid_path
      frames = []
      a = int(100/count)
      first_frame = np.random.randint(0,a)
      temp_video = video_path.split('/')[-1]
      for i,frame in enumerate(frame_extract(video_path)):
        frames.append(transform(frame))
        if(len(frames) == count):
          break
      frames = torch.stack(frames)
      frames = frames[:count]
      return frames
#extract a from from video
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image

im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])
video_fil = glob.glob('/content/drive/My Drive/Face_only_data/*.mp4')
print("Total no of videos :" , len(video_fil))
print(video_fil)
count = 0;
for i in video_fil:
  try:
    count+=1
    validate_video(i,train_transforms)
  except:
    print("Number of video processed: " , count ," Remaining : " , (len(video_fil) - count))
    print("Corrupted video is : " , i)
    continue
print((len(video_fil) - count))
# Out:
# Total no of videos : 623
# ['/content/drive/My Drive/Face_only_data/307.mp4', '/content/drive/My Drive/Face_only_data/220.mp4', '/content/drive/My Drive/Face_only_data/174.mp4', '/content/drive/My Drive/Face_only_data/16.mp4', '/content/drive/My Drive/Face_only_data/520.mp4', '/content/drive/My Drive/Face_only_data/349.mp4', '/content/drive/My Drive/Face_only_data/573.mp4', '/content/drive/My Drive/Face_only_data/103.mp4', '/content/drive/My Drive/Face_only_data/424.mp4', '/content/drive/My Drive/Face_only_data/33.mp4', '/content/drive/My Drive/Face_only_data/287.mp4', '/content/drive/My Drive/Face_only_data/128.mp4', '/content/drive/My Drive/Face_only_data/626.mp4', '/content/drive/My Drive/Face_only_data/29.mp4', '/content/drive/My Drive/Face_only_data/594.mp4', '/content/drive/My Drive/Face_only_data/201.mp4', '/content/drive/My Drive/Face_only_data/73.mp4', '/content/drive/My Drive/Face_only_data/110.mp4', '/content/drive/My Drive/Face_only_data/515.mp4', '/content/drive/My Drive/Face_only_data/43.mp4', '/content/drive/My Drive/Face_only_data/140.mp4', '/content/drive/My Drive/Face_only_data/286.mp4', '/content/drive/My Drive/Face_only_data/267.mp4', '/content/drive/My Drive/Face_only_data/162.mp4', '/content/drive/My Drive/Face_only_data/79.mp4', '/content/drive/My Drive/Face_only_data/70.mp4', '/content/drive/My Drive/Face_only_data/246.mp4', '/content/drive/My Drive/Face_only_data/173.mp4', '/content/drive/My Drive/Face_only_data/169.mp4', '/content/drive/My Drive/Face_only_data/582.mp4', '/content/drive/My Drive/Face_only_data/327.mp4', '/content/drive/My Drive/Face_only_data/311.mp4', '/content/drive/My Drive/Face_only_data/315.mp4', '/content/drive/My Drive/Face_only_data/545.mp4', '/content/drive/My Drive/Face_only_data/625.mp4', '/content/drive/My Drive/Face_only_data/245.mp4', '/content/drive/My Drive/Face_only_data/513.mp4', '/content/drive/My Drive/Face_only_data/519.mp4', '/content/drive/My Drive/Face_only_data/113.mp4', '/content/drive/My Drive/Face_only_data/484.mp4', '/content/drive/My Drive/Face_only_data/294.mp4', '/content/drive/My Drive/Face_only_data/578.mp4', '/content/drive/My Drive/Face_only_data/64.mp4', '/content/drive/My Drive/Face_only_data/604.mp4', '/content/drive/My Drive/Face_only_data/416.mp4', '/content/drive/My Drive/Face_only_data/329.mp4', '/content/drive/My Drive/Face_only_data/368.mp4', '/content/drive/My Drive/Face_only_data/69.mp4', '/content/drive/My Drive/Face_only_data/605.mp4', '/content/drive/My Drive/Face_only_data/216.mp4', '/content/drive/My Drive/Face_only_data/620.mp4', '/content/drive/My Drive/Face_only_data/108.mp4', '/content/drive/My Drive/Face_only_data/297.mp4', '/content/drive/My Drive/Face_only_data/171.mp4', '/content/drive/My Drive/Face_only_data/90.mp4', '/content/drive/My Drive/Face_only_data/539.mp4', '/content/drive/My Drive/Face_only_data/523.mp4', '/content/drive/My Drive/Face_only_data/588.mp4', '/content/drive/My Drive/Face_only_data/57.mp4', '/content/drive/My Drive/Face_only_data/175.mp4', '/content/drive/My Drive/Face_only_data/351.mp4', '/content/drive/My Drive/Face_only_data/156.mp4', '/content/drive/My Drive/Face_only_data/61.mp4', '/content/drive/My Drive/Face_only_data/566.mp4', '/content/drive/My Drive/Face_only_data/226.mp4', '/content/drive/My Drive/Face_only_data/210.mp4', '/content/drive/My Drive/Face_only_data/281.mp4', '/content/drive/My Drive/Face_only_data/194.mp4', '/content/drive/My Drive/Face_only_data/164.mp4', '/content/drive/My Drive/Face_only_data/397.mp4', '/content/drive/My Drive/Face_only_data/357.mp4', '/content/drive/My Drive/Face_only_data/419.mp4', '/content/drive/My Drive/Face_only_data/141.mp4', '/content/drive/My Drive/Face_only_data/154.mp4', '/content/drive/My Drive/Face_only_data/263.mp4', '/content/drive/My Drive/Face_only_data/334.mp4', '/content/drive/My Drive/Face_only_data/552.mp4', '/content/drive/My Drive/Face_only_data/597.mp4', '/content/drive/My Drive/Face_only_data/592.mp4', '/content/drive/My Drive/Face_only_data/118.mp4', '/content/d ...
# 0

# %%
#to load preprocessod video to memory
import json
import glob
import numpy as np
import cv2
import copy
import random

video_files = glob.glob('/content/drive/My Drive/Face_only_data/*.mp4')
random.shuffle(video_files)
random.shuffle(video_files)
frame_count = []

for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<100):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))

print("frames are " , frame_count)
print("Total no of video: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames are  [148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 142, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 141, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 146, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 142, 148, 148, 148, 148, 148, 148, 144, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 138, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 128, 148, 146, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 100, 148, 148, 148, 114, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148, 148]
# Total no of video:  617
# Average frame per video: 147.77471636952998

# %%
# load the video name and labels from csv
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
class video_dataset(Dataset):
    def __init__(self,video_names,labels,sequence_length = 60,transform = None):
        self.video_names = video_names
        self.labels = labels
        self.transform = transform
        self.count = sequence_length
    def __len__(self):
        return len(self.video_names)
    def __getitem__(self,idx):
        video_path = self.video_names[idx]
        frames = []
        a = int(100/self.count)
        first_frame = np.random.randint(0,a)

        temp_video = video_path.split('/')[-1]
        print("Shape of labels: ", self.labels.shape)
        print("File name: ", temp_video)
        matching_rows = self.labels.loc[self.labels["file"] == temp_video].index.values
        if len(matching_rows) > 0:
            label = self.labels.iloc[matching_rows[0], 1]
        else:
          raise Exception("Error: No matching row found for video '{}'".format(temp_video))
        if(label == 'FAKE'):
          label = 0
        if(label == 'REAL'):
          label = 1
          
        for i,frame in enumerate(self.frame_extract(video_path)):
          frames.append(self.transform(frame))
          if(len(frames) == self.count):
            break
        frames = torch.stack(frames)
        frames = frames[:self.count]
        return frames,label
    def frame_extract(self,path):
      vidObj = cv2.VideoCapture(path) 
      success = 1
      while success:
          success, image = vidObj.read()
          if success:
              yield image
#plot the image
def im_plot(tensor):
    image = tensor.cpu().numpy().transpose(1,2,0)
    b,g,r = cv2.split(image)
    image = cv2.merge((r,g,b))
    image = image*[0.22803, 0.22145, 0.216989] +  [0.43216, 0.394666, 0.37645]
    image = image*255.0
    plt.imshow(image.astype(int))
    plt.show()

# %%
def number_of_real_and_fake_videos(data_list):
    header_list = ["file","label"]
    lab = pd.read_csv('data.csv', names=header_list, sep=',')
    fake = 0
    real = 0
    for i in data_list:
        temp_video = i.split('/')[-1]
        matching_rows = lab[lab['file'] == temp_video]
        if matching_rows.empty:
            continue
        label = matching_rows.iloc[0, 1]
        if(label == 'FAKE'):
            fake += 1
        if(label == 'REAL'):
            real += 1
    return real, fake

# %%
# load the labels and video in data loader
import random
import pandas as pd
from sklearn.model_selection import train_test_split

header_list = ["file","label"]
labels = pd.read_csv('data.csv',names=header_list)
train_videos = video_files[:475]
valid_videos = video_files[475:]
print("train : " , len(train_videos))
print("test : " , len(valid_videos))
train_videos,valid_videos = train_test_split(data,test_size = 0.2)
print(train_videos)

print("TRAIN: ", "Real:",number_of_real_and_fake_videos(train_videos)[0]," Fake:",number_of_real_and_fake_videos(train_videos)[1])
print("TEST: ", "Real:",number_of_real_and_fake_videos(valid_videos)[0]," Fake:",number_of_real_and_fake_videos(valid_videos)[1])


im_size = 112
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

train_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])

test_transforms = transforms.Compose([
                                        transforms.ToPILImage(),
                                        transforms.Resize((im_size,im_size)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(mean,std)])
train_data = video_dataset(train_videos,labels,sequence_length = 10,transform = train_transforms)
#print(train_data)
val_data = video_dataset(valid_videos,labels,sequence_length = 10,transform = train_transforms)
train_loader = DataLoader(train_data,batch_size = 4,shuffle = True,num_workers = 4)
valid_loader = DataLoader(val_data,batch_size = 4,shuffle = True,num_workers = 4)
image,label = train_data[0]
im_plot(image[0,:,:,:])
# Out:
# train :  475
# test :  145
# /usr/local/lib/python3.9/dist-packages/torch/utils/data/dataloader.py:554: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# TRAIN:  Real: 171  Fake: 304
# TEST:  Real: 67  Fake: 78
# Shape of labels:  (800, 2)
# File name:  307.mp4

# %%
#Model with feature visualization
from torch import nn
from torchvision import models
class Model(nn.Module):
    def __init__(self, num_classes,latent_dim= 2048, lstm_layers=1 , hidden_dim = 2048, bidirectional = False):
        super(Model, self).__init__()
        model = models.resnext50_32x4d(pretrained = True) #Residual Network CNN
        self.model = nn.Sequential(*list(model.children())[:-2])
        self.lstm = nn.LSTM(latent_dim,hidden_dim, lstm_layers,  bidirectional)
        self.relu = nn.LeakyReLU()
        self.dp = nn.Dropout(0.4)
        self.linear1 = nn.Linear(2048,num_classes)
        self.avgpool = nn.AdaptiveAvgPool2d(1)
    def forward(self, x):
        batch_size,seq_length, c, h, w = x.shape
        x = x.view(batch_size * seq_length, c, h, w)
        fmap = self.model(x)
        x = self.avgpool(fmap)
        x = x.view(batch_size,seq_length,2048)
        x_lstm,_ = self.lstm(x,None)
        return fmap,self.dp(self.linear1(torch.mean(x_lstm,dim = 1)))

# %%
model = Model(2).cuda()
a,b = model(torch.from_numpy(np.empty((1,20,3,112,112))).type(torch.cuda.FloatTensor))
# Out:
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNeXt50_32X4D_Weights.IMAGENET1K_V1`. You can also use `weights=ResNeXt50_32X4D_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
import torch
from torch.autograd import Variable
import time
import os
import sys
import os
def train_epoch(epoch, num_epochs, data_loader, model, criterion, optimizer):
    model.train()
    losses = AverageMeter()
    accuracies = AverageMeter()
    t = []
    for i, (inputs, targets) in enumerate(data_loader):
        if torch.cuda.is_available():
            targets = targets.type(torch.cuda.LongTensor)
            inputs = inputs.cuda()
        _,outputs = model(inputs)
        loss  = criterion(outputs,targets.type(torch.cuda.LongTensor))
        acc = calculate_accuracy(outputs, targets.type(torch.cuda.LongTensor))
        losses.update(loss.item(), inputs.size(0))
        accuracies.update(acc, inputs.size(0))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        sys.stdout.write(
                "\r[Epoch %d/%d] [Batch %d / %d] [Loss: %f, Acc: %.2f%%]"
                % (
                    epoch,
                    num_epochs,
                    i,
                    len(data_loader),
                    losses.avg,
                    accuracies.avg))
    torch.save(model.state_dict(),'/content/checkpoint.pt')
    return losses.avg,accuracies.avg
def test(epoch,model, data_loader ,criterion):
    print('Testing')
    model.eval()
    losses = AverageMeter()
    accuracies = AverageMeter()
    pred = []
    true = []
    count = 0
    with torch.no_grad():
        for i, (inputs, targets) in enumerate(data_loader):
            if torch.cuda.is_available():
                targets = targets.cuda().type(torch.cuda.FloatTensor)
                inputs = inputs.cuda()
            _,outputs = model(inputs)
            loss = torch.mean(criterion(outputs, targets.type(torch.cuda.LongTensor)))
            acc = calculate_accuracy(outputs,targets.type(torch.cuda.LongTensor))
            _,p = torch.max(outputs,1) 
            true += (targets.type(torch.cuda.LongTensor)).detach().cpu().numpy().reshape(len(targets)).tolist()
            pred += p.detach().cpu().numpy().reshape(len(p)).tolist()
            losses.update(loss.item(), inputs.size(0))
            accuracies.update(acc, inputs.size(0))
            sys.stdout.write(
                    "\r[Batch %d / %d]  [Loss: %f, Acc: %.2f%%]"
                    % (
                        i,
                        len(data_loader),
                        losses.avg,
                        accuracies.avg
                        )
                    )
        print('\nAccuracy {}'.format(accuracies.avg))
    return true,pred,losses.avg,accuracies.avg
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()
    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
def calculate_accuracy(outputs, targets):
    batch_size = targets.size(0)

    _, pred = outputs.topk(1, 1, True)
    pred = pred.t()
    correct = pred.eq(targets.view(1, -1))
    n_correct_elems = correct.float().sum().item()
    return 100* n_correct_elems / batch_size

# %%
import seaborn as sn
#Output confusion matrix
def print_confusion_matrix(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    print('True positive = ', cm[0][0])
    print('False positive = ', cm[0][1])
    print('False negative = ', cm[1][0])
    print('True negative = ', cm[1][1])
    print('\n')
    df_cm = pd.DataFrame(cm, range(2), range(2))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}) # font size
    plt.ylabel('Actual label', size = 20)
    plt.xlabel('Predicted label', size = 20)
    plt.xticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.yticks(np.arange(2), ['Fake', 'Real'], size = 16)
    plt.ylim([2, 0])
    plt.show()
    calculated_acc = (cm[0][0]+cm[1][1])/(cm[0][0]+cm[0][1]+cm[1][0]+ cm[1][1])
    print("Calculated Accuracy",calculated_acc*100)

# %%
def plot_loss(train_loss_avg,test_loss_avg,num_epochs):
  loss_train = train_loss_avg
  loss_val = test_loss_avg
  print(num_epochs)
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training loss')
  # plt.plot(epochs, loss_val, 'b', label='validation loss')
  plt.title('Training loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()
def plot_accuracy(train_accuracy,test_accuracy,num_epochs):
  loss_train = train_accuracy
  loss_val = test_accuracy
  epochs = range(1,num_epochs+1)
  plt.plot(epochs, loss_train, 'g', label='Training accuracy')
  # plt.plot(epochs, loss_val, 'b', label='validation accuracy')
  plt.title('Training accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
#14 Minutes 10 Seconds to Run
from sklearn.metrics import confusion_matrix, accuracy_score
#learning rate
lr = 1e-5#0.001
#number of epochs 
num_epochs = 20

optimizer = torch.optim.Adam(model.parameters(), lr= lr,weight_decay = 1e-5)

#class_weights = torch.from_numpy(np.asarray([1,15])).type(torch.FloatTensor).cuda()
#criterion = nn.CrossEntropyLoss(weight = class_weights).cuda()
criterion = nn.CrossEntropyLoss().cuda()
train_loss_avg =[]
train_accuracy = []
test_loss_avg = []
test_accuracy = []
for epoch in range(1,num_epochs+1):
    l, acc = train_epoch(epoch,num_epochs,train_loader,model,criterion,optimizer)
    train_loss_avg.append(l)
    train_accuracy.append(acc)
    true,pred,tl,t_acc = test(epoch,model,valid_loader,criterion)
    test_loss_avg.append(tl)
    test_accuracy.append(t_acc)
plot_loss(train_loss_avg,test_loss_avg,len(train_loss_avg))
plot_accuracy(train_accuracy,test_accuracy,len(train_accuracy))
overall_acc = accuracy_score(true, pred)
print("Overall accuracy:", overall_acc)
print(confusion_matrix(true,pred))
print_confusion_matrix(true,pred)
# Out:
# Streaming output truncated to the last 5000 lines.
# 576.mp4Shape of labels: File name:  (800, 2)
# 359.mp4
#
#  File name: 120.mp4
# Shape of labels:  208.mp4Shape of labels:   (800, 2)(800, 2)
#
# File name:  File name: 278.mp4
#
#  255.mp4Shape of labels:
#  (800, 2)Shape of labels:
# Shape of labels: (800, 2)File name:
#  File name: (800, 2) 429.mp4640.mp4
#
#
# File name: Shape of labels:  (800, 2)
#  File name:  166.mp419.mp4
#
# Shape of labels:  Shape of labels:
# (800, 2)File name:  42.mp4
# (800, 2)Shape of labels:
# File name:  179.mp4
#  (800, 2)
# File name:  153.mp4
# [Batch 30 / 37]  [Loss: 0.824403, Acc: 73.39%]Shape of labels:  (800, 2)
# File name:  457.mp4
# [Batch 36 / 37]  [Loss: 0.809519, Acc: 73.79%]
# Accuracy 73.79310344827586
# Shape of labels:  Shape of labels: (800, 2) Shape of labels:
# (800, 2)(800, 2)File name: Shape of labels:
#   File name: 337.mp4
# 103.mp4
# (800, 2)
# File name:  503.mp4
#
# File name:  2.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:
# 572.mp4 (800, 2)
# Shape of labels: Shape of labels: File name:   585.mp4(800, 2)
#
# File name:   (800, 2)Shape of labels: 554.mp4
#
# File name:   (800, 2)4.mp4
# 410.mp4
# File name:  Shape of labels:
# Shape of labels:   Shape of labels: (800, 2)(800, 2)
# Shape of labels:
# File name:  File name:   (800, 2)
# 521.mp4(800, 2)File name:
#  321.mp4328.mp4File name:
#
#
#  Shape of labels:  221.mp4Shape of labels:  (800, 2)
# (800, 2)
# Shape of labels: File name:  387.mp4
#
# (800, 2)
# File name: Shape of labels:   191.mp4(800, 2)
#
# File name:  Shape of labels: 425.mp4
# (800, 2)File name:
# File name:  176.mp4
#  306.mp4Shape of labels:
#  Shape of labels: (800, 2)Shape of labels:
#  File name:
# (800, 2)File name: Shape of labels:  (800, 2) 246.mp4
#
# File name:  (800, 2)517.mp4Shape of labels: 600.mp4
#
#
# File name:   82.mp4(800, 2)
# Shape of labels:
#  File name: (800, 2) Shape of labels:
# Shape of labels: 112.mp4 File name:
#  (800, 2) (800, 2)
# 551.mp4
#
# File name:  423.mp4
# File name:  569.mp4Shape of labels:
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name:  File name: (800, 2) 405.mp4144.mp4
#
# Shape of labels: (800, 2)File name:   (800, 2)270.mp4
#
# File name:
# 426.mp4Shape of labels:
# File name:  139.mp4
#
# Shape of labels: Shape of labels:  (800, 2) Shape of labels: Shape of labels:
# (800, 2)101.mp4File name:
#
# (800, 2)
# File name: File name: (800, 2)
# 71.mp4File name:
# [Epoch 17/20] [Batch 0 / 119] [Loss: 0.018194, Acc: 100.00%]244.mp4
# 312.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name:  File name:  96.mp4
# 99.mp4
# Shape of labels:  (800, 2)
# File name:  46.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  587.mp4
# (800, 2)
# File name:  220.mp4Shape of labels:
#  Shape of labels:  (800, 2)
# File name:  (800, 2)250.mp4
#
# File name:  400.mp4
# [Epoch 17/20] [Batch 1 / 119] [Loss: 0.184807, Acc: 100.00%]Shape of labels:  (800, 2)
# File name: Shape of labels:   118.mp4
# (800, 2)
# File name:  Shape of labels: 279.mp4
#
# (800, 2) File name:  338.mp4Shape of labels:
#
#  (800, 2)File name:  508.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 2 / 119] [Loss: 0.218476, Acc: 100.00%]
# Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)
# File name:  241.mp4
# File name: Shape of labels:  (800, 2)
# File name:  257.mp4
# 127.mp4
# Shape of labels:  (800, 2)
# File name:  613.mp4
# [Epoch 17/20] [Batch 3 / 119] [Loss: 0.173494, Acc: 100.00%]Shape of labels:  (800, 2)
# File name:  417.mp4
# Shape of labels:  (800, 2)
# File name:  222.mp4
# Shape of labels:  (800, 2)
# File name:  147.mp4
# Shape of labels:  (800, 2)
# File name:  1.mp4
# [Epoch 17/20] [Batch 4 / 119] [Loss: 0.196052, Acc: 100.00%]Shape of labels:  Shape of labels: (800, 2)
# File name: (800, 2) 197.mp4
#
# File name:  558.mp4Shape of labels:
#  (800, 2)
# File name:  104.mp4
# [Epoch 17/20] [Batch 5 / 119] [Loss: 0.166506, Acc: 100.00%]Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
# File name:  594.mp4
# 199.mp4
# Shape of labels:  (800, 2)Shape of labels:  (800, 2)
# File name:  605.mp4
#
# [Epoch 17/20] [Batch 6 / 119] [Loss: 0.176059, Acc: 100.00%]113.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  397.mp4
# (800, 2)
# Shape of labels: File name:  316.mp4
# (800, 2)
# File name: Shape of labels:   196.mp4
# [Epoch 17/20] [Batch 7 / 119] [Loss: 0.159511, Acc: 100.00%]
# File name:  177.mp4
# Shape of labels:  Shape of labels: (800, 2)
#  File name: (800, 2)
# 511.mp4File name:
#  163.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# File name:  227.mp4
# (800, 2)
# [Epoch 17/20] [Batch 8 / 119] [Loss: 0.145230, Acc: 100.00%] 292.mp4Shape of labels:
# (800, 2)
# File name:  523.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:  624.mp4
# 14.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 9 / 119] [Loss: 0.144686, Acc: 100.00%]574.mp4Shape of labels:
# (800, 2)
# File name: Shape of labels: Shape of labels:   301.mp4 (800, 2)
# (800, 2)
#
# File name:  9.mp4
# File name:  309.mp4Shape of labels:  (800, 2)
# File name:
# 344.mp4
# [Epoch 17/20] [Batch 10 / 119] [Loss: 0.134010, Acc: 100.00%]Shape of labels:  (800, 2)
# File name:  198.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  167.mp4
# (800, 2)
# File name:  151.mp4Shape of labels:  (800, 2)
# File name:
# 123.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 11 / 119] [Loss: 0.151982, Acc: 100.00%]556.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
# File name:
# File name:   501.mp4110.mp4
#
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 12 / 119] [Loss: 0.182069, Acc: 98.08%] 160.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   290.mp4
# (800, 2)
# File name:  Shape of labels: 550.mp4
# (800, 2)
# Shape of labels: File name:  39.mp4
# (800, 2)
# [Epoch 17/20] [Batch 13 / 119] [Loss: 0.184773, Acc: 98.21%]
# Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)File name:
# File name:   15.mp4414.mp4
#
# Shape of labels:  Shape of labels:  (800, 2)
# File name:  318.mp4(800, 2)
#
# File name:  125.mp4
# [Epoch 17/20] [Batch 14 / 119] [Loss: 0.185498, Acc: 98.33%]Shape of labels:  (800, 2)
# File name: Shape of labels:   592.mp4(800, 2)
#
# Shape of labels: File name:  499.mp4 (800, 2)
#
# File name:  243.mp4Shape of labels:
#  (800, 2)
# [Epoch 17/20] [Batch 15 / 119] [Loss: 0.175734, Acc: 98.44%] 515.mp4Shape of labels:
#  (800, 2)
# Shape of labels: File name:   (800, 2)183.mp4
#
# File name:  233.mp4Shape of labels:
# (800, 2)
# File name: Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 16 / 119] [Loss: 0.176508, Acc: 98.53%]File name:  487.mp4
# Shape of labels:  (800, 2)475.mp4
#
# File name:  252.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:   (800, 2)
# 3.mp4File name:
#  236.mp4
# [Epoch 17/20] [Batch 17 / 119] [Loss: 0.168155, Acc: 98.61%]Shape of labels: Shape of labels:  (800, 2)
# File name:  (800, 2)
# Shape of labels:  (800, 2) 149.mp4File name:
#
# File name:   271.mp4Shape of labels:
# 72.mp4 (800, 2)
#
# File name:  Shape of labels:
# 510.mp4 (800, 2)
# File name:  146.mp4
# [Epoch 17/20] [Batch 18 / 119] [Loss: 0.161404, Acc: 98.68%]Shape of labels:  Shape of labels: (800, 2)
#  File name:  602.mp4(800, 2)
#
# File name:  150.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
# File name:
# File name:  234.mp4
# 296.mp4
# [Epoch 17/20] [Batch 20 / 119] [Loss: 0.165700, Acc: 98.81%]Shape of labels: Shape of labels:   (800, 2)(800, 2)
# File name:  593.mp4
#
# File name:  320.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  (800, 2)
# File name:  102.mp4File name:
#  262.mp4Shape of labels:
#  (800, 2)
# File name:  424.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
# File name:
# File name:   73.mp4
# 552.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 22 / 119] [Loss: 0.193039, Acc: 97.83%]File name:  Shape of labels:  75.mp4(800, 2)
#
# File name:  567.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:   (800, 2)251.mp4
#
# File name:  526.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:  Shape of labels:   (800, 2)(800, 2)
# File name:  190.mp4
# 171.mp4
#
# File name: Shape of labels:   (800, 2)394.mp4
#
# File name:  353.mp4Shape of labels:
# (800, 2)
# [Epoch 17/20] [Batch 23 / 119] [Loss: 0.187026, Acc: 97.92%]File name:  339.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   514.mp4
# 206.mp4
# Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)File name:
# 621.mp4
# [Epoch 17/20] [Batch 24 / 119] [Loss: 0.254397, Acc: 96.00%]348.mp4
# Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)
# File name:  File name:  413.mp4
# Shape of labels: 398.mp4
#  (800, 2)
# Shape of labels: File name:  (800, 2) 314.mp4
# File name:
#  507.mp4
# [Epoch 17/20] [Batch 25 / 119] [Loss: 0.264622, Acc: 95.19%]Shape of labels:  (800, 2)
# File name:  606.mp4
# Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)
# File name:  File name: 311.mp4
#  267.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 26 / 119] [Loss: 0.256398, Acc: 95.37%]95.mp4
# Shape of labels:  (800, 2)
# File name:  54.mp4Shape of labels:  (800, 2)
# File name:  207.mp4
#
# Shape of labels:  Shape of labels: (800, 2)
# File name:   356.mp4(800, 2)
# File name:
#  557.mp4
# [Epoch 17/20] [Batch 27 / 119] [Loss: 0.253681, Acc: 95.54%](800, 2)
# File name:  286.mp4Shape of labels:  (800, 2)
# File name:  231.mp4
#
# Shape of labels:  (800, 2)
# File name:  111.mp4
# Shape of labels:  (800, 2)
# File name:  79.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 28 / 119] [Loss: 0.246876, Acc: 95.69%]
# Shape of labels: Shape of labels:  (800, 2) (800, 2)
# File name:
#  404.mp4
# File name: Shape of labels:  (800, 2)
# File name:  210.mp4
#  346.mp4
# Shape of labels:  (800, 2)
# File name:  379.mp4
# [Epoch 17/20] [Batch 29 / 119] [Loss: 0.246880, Acc: 95.83%]Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# File name:  360.mp4
# 482.mp4
# Shape of labels:  (800, 2)
# File name:  559.mp4
# [Epoch 17/20] [Batch 30 / 119] [Loss: 0.251099, Acc: 95.97%](800, 2)
# Shape of labels: File name:  (800, 2)
# File name:  528.mp4
#
# 25.mp4Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# 382.mp4File name:
#  396.mp4
# [Epoch 17/20] [Batch 31 / 119] [Loss: 0.244902, Acc: 96.09%]Shape of labels:  (800, 2)
# File name:  86.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# File name:  169.mp4(800, 2)
#
# File name:  116.mp4
# Shape of labels:  (800, 2)
# File name:  577.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 32 / 119] [Loss: 0.248191, Acc: 96.21%]273.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  280.mp4
#  (800, 2)
# File name:  68.mp4
# Shape of labels:  (800, 2)
# File name:  114.mp4
# Shape of labels:  (800, 2)
# File name:  205.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 33 / 119] [Loss: 0.241317, Acc: 96.32%] 226.mp4
# Shape of labels:  (800, 2)
# File name:  92.mp4
# Shape of labels:  (800, 2)
# File name:  421.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 35 / 119] [Loss: 0.237788, Acc: 96.53%]File name: Shape of labels:   181.mp4
# (800, 2)
# File name: Shape of labels:   (800, 2)276.mp4
#
# File name:  327.mp4
# Shape of labels:  (800, 2)
# File name:  340.mp4
# Shape of labels:  (800, 2)
# File name:  619.mp4
# Shape of labels:  (800, 2)
# File name:  342.mp4
# Shape of labels:  (800, 2)
# File name:  249.mp4
# Shape of labels:  (800, 2)
# File name:  281.mp4
# Shape of labels:  (800, 2)
# File name:  380.mp4
# [Epoch 17/20] [Batch 36 / 119] [Loss: 0.236238, Acc: 96.62%] (800, 2)
# File name:  33.mp4
# Shape of labels:  (800, 2)
# File name:  261.mp4
# Shape of labels:  (800, 2)
# File name:  527.mp4
# Shape of labels:  (800, 2)Shape of labels:
# [Epoch 17/20] [Batch 38 / 119] [Loss: 0.231629, Acc: 96.79%]File name: (800, 2)
# File name: 529.mp4 60.mp4
#
# Shape of labels:  (800, 2)
# Shape of labels: File name:  361.mp4
#  (800, 2)
# File name:  268.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:   (800, 2)
# File name:  582.mp4
# 148.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:   (800, 2)489.mp4
#
# File name:  74.mp4
# [Epoch 17/20] [Batch 39 / 119] [Loss: 0.227314, Acc: 96.88%]Shape of labels:  Shape of labels:  (800, 2)
# (800, 2)
# File name: File name:   154.mp4
# 381.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name: (800, 2)
# 392.mp4File name:
#  90.mp4Shape of labels:
# [Epoch 17/20] [Batch 40 / 119] [Loss: 0.222350, Acc: 96.95%](800, 2)
# File name:  571.mp4
# Shape of labels:  (800, 2)
# File name:  393.mp4
# Shape of labels:  (800, 2)
# File name:  478.mp4
# Shape of labels:  (800, 2)
# File name:  203.mp4
# [Epoch 17/20] [Batch 41 / 119] [Loss: 0.220790, Acc: 97.02%]
# File name: Shape of labels:   378.mp4(800, 2)
#
# File name:  32.mp4Shape of labels:
#  (800, 2)
# Shape of labels: File name:   (800, 2)
# 36.mp4File name:
#  563.mp4
# [Epoch 17/20] [Batch 42 / 119] [Loss: 0.217976, Acc: 97.09%]Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
#  File name: 616.mp4
# 13.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:  (800, 2)
# File name:  365.mp4
#  532.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 43 / 119] [Loss: 0.213947, Acc: 97.16%]362.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  516.mp4File name:  88.mp4
#
# Shape of labels:  (800, 2)
# File name:  263.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 45 / 119] [Loss: 0.209016, Acc: 97.28%]Shape of labels:  (800, 2)
# 622.mp4File name:  105.mp4
#
# Shape of labels: Shape of labels:  (800, 2) (800, 2)
#
# File name: File name:  269.mp4
# 186.mp4
# Shape of labels:  (800, 2)Shape of labels:
# (800, 2)File name:
#  File name: 27.mp4
# 341.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   596.mp4406.mp4
#
# [Epoch 17/20] [Batch 46 / 119] [Loss: 0.253961, Acc: 95.74%]Shape of labels:  (800, 2)
# File name: Shape of labels:   65.mp4(800, 2)
#
# File name: Shape of labels:   (800, 2)41.mp4
#
# File name:  504.mp4
# Shape of labels:  (800, 2)
# File name:  483.mp4
# [Epoch 17/20] [Batch 47 / 119] [Loss: 0.255968, Acc: 95.83%](800, 2)
# File name:  Shape of labels: 322.mp4
# (800, 2)
# File name: Shape of labels:  22.mp4
# (800, 2)
# Shape of labels: File name:   48.mp4(800, 2)
#
# File name:  609.mp4
# [Epoch 17/20] [Batch 48 / 119] [Loss: 0.255925, Acc: 95.41%]
# File name:  535.mp4
# Shape of labels: Shape of labels:  (800, 2) (800, 2)
#
# File name:  519.mp4
# File name:  211.mp4
# Shape of labels:  (800, 2)
# File name:  561.mp4
# [Epoch 17/20] [Batch 49 / 119] [Loss: 0.254409, Acc: 95.50%] (800, 2)
# File name: Shape of labels:  (800, 2)
# 409.mp4
# File name:  229.mp4Shape of labels:
# (800, 2)
# File name:  64.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 50 / 119] [Loss: 0.258713, Acc: 94.61%]
# Shape of labels:  (800, 2)Shape of labels:  (800, 2)
# File name:  240.mp4
#
# File name:  505.mp4Shape of labels:  (800, 2)
# File name:  78.mp4
#
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 51 / 119] [Loss: 0.258039, Acc: 94.23%]File name:  297.mp4
# Shape of labels: Shape of labels:  (800, 2)
# (800, 2)File name:
# File name:  375.mp4
# 187.mp4
# Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# File name: 485.mp4
# 6.mp4
# [Epoch 17/20] [Batch 52 / 119] [Loss: 0.253373, Acc: 94.34%]Shape of labels:  (800, 2)
# File name:  Shape of labels:  (800, 2)
# 164.mp4File name:
#  133.mp4Shape of labels:
# (800, 2)
# Shape of labels: File name:   119.mp4
# (800, 2)
# File name:  130.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 54 / 119] [Loss: 0.248514, Acc: 94.55%]File name:  388.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
#  File name: 539.mp4
# 136.mp4
# Shape of labels:  (800, 2)
# File name:  332.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
#  615.mp4File name:
#  29.mp4
# Shape of labels:  Shape of labels: (800, 2) (800, 2)
#
# File name: File name:   541.mp4195.mp4
#
# [Epoch 17/20] [Batch 55 / 119] [Loss: 0.245813, Acc: 94.64%](800, 2)
# File name: Shape of labels:   486.mp4
# (800, 2)
# File name:  Shape of labels: 260.mp4
#  (800, 2)
# File name:  334.mp4
# Shape of labels:  (800, 2)
# File name:  61.mp4
# [Epoch 17/20] [Batch 56 / 119] [Loss: 0.245796, Acc: 94.74%]
# File name:  17.mp4
# Shape of labels:  (800, 2)
# File name:  513.mp4
# Shape of labels:  (800, 2)
# File name:  549.mp4
# Shape of labels:  (800, 2)
# File name:  140.mp4
# [Epoch 17/20] [Batch 57 / 119] [Loss: 0.242413, Acc: 94.83%] (800, 2)
# File name:  580.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 363.mp4
# 525.mp4
# Shape of labels:  (800, 2)
# File name:  564.mp4
# [Epoch 17/20] [Batch 58 / 119] [Loss: 0.238604, Acc: 94.92%]
# (800, 2)File name: Shape of labels:   350.mp4(800, 2)
#
# File name:  Shape of labels: 108.mp4
# (800, 2)
# File name: Shape of labels:   214.mp4(800, 2)
#
# File name:  493.mp4
# [Epoch 17/20] [Batch 59 / 119] [Loss: 0.235626, Acc: 95.00%](800, 2)
# File name:  538.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   498.mp4544.mp4
#
# Shape of labels:  (800, 2)
# File name:  288.mp4
# Shape of labels:  (800, 2)
# File name:  10.mp4
# [Epoch 17/20] [Batch 60 / 119] [Loss: 0.234615, Acc: 95.08%]Shape of labels:  (800, 2)
# File name: Shape of labels:   578.mp4(800, 2)
#
# File name:  399.mp4
# Shape of labels:  (800, 2)
# File name:  162.mp4
# Shape of labels:  (800, 2)
# File name:  137.mp4
# [Epoch 17/20] [Batch 62 / 119] [Loss: 0.238552, Acc: 94.84%]Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 180.mp4 420.mp4
#
# Shape of labels:  (800, 2)
# File name:  56.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:  77.mp4
#  (800, 2)
# File name: Shape of labels:   492.mp4(800, 2)
#
# File name: Shape of labels:   175.mp4(800, 2)
#
# File name:  597.mp4
# [Epoch 17/20] [Batch 63 / 119] [Loss: 0.234905, Acc: 94.92%]
# File name: Shape of labels:   (800, 2)275.mp4
#
# File name:  Shape of labels: 495.mp4
# (800, 2)
# File name: Shape of labels:   67.mp4(800, 2)
#
# File name:  349.mp4
# [Epoch 17/20] [Batch 64 / 119] [Loss: 0.234194, Acc: 95.00%]
# File name:  598.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:  (800, 2)
# 293.mp4File name:
#  232.mp4
# Shape of labels:  (800, 2)
# File name:  579.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 65 / 119] [Loss: 0.233761, Acc: 94.70%]
# Shape of labels:  Shape of labels:  (800, 2)
# (800, 2)File name:
#  File name: 80.mp4
# 575.mp4
# Shape of labels:  (800, 2)
# File name:  87.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 67 / 119] [Loss: 0.227362, Acc: 94.85%]  415.mp4(800, 2)
#
# File name:  Shape of labels: 562.mp4
# (800, 2)
# File name: Shape of labels:  (800, 2)
# 20.mp4File name:
#  419.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:  494.mp4
#  (800, 2)
# Shape of labels:  (800, 2)
# File name:  324.mp4
# File name:  330.mp4
# Shape of labels:  (800, 2)
# File name:  307.mp4
# [Epoch 17/20] [Batch 68 / 119] [Loss: 0.227739, Acc: 94.93%] (800, 2)
# File name:  135.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   70.mp4(800, 2)
#
# File name:  55.mp4
# Shape of labels:  (800, 2)
# File name:  43.mp4
# [Epoch 17/20] [Batch 69 / 119] [Loss: 0.227339, Acc: 95.00%]Shape of labels:  (800, 2)Shape of labels:
#  (800, 2)
# File name: File name:   121.mp4225.mp4
#
# Shape of labels:  Shape of labels: (800, 2)
#  (800, 2)File name:
#  File name:  422.mp463.mp4
#
# [Epoch 17/20] [Batch 70 / 119] [Loss: 0.225745, Acc: 95.07%]Shape of labels:  (800, 2)
# Shape of labels: File name:   367.mp4(800, 2)
#
# File name: Shape of labels:  604.mp4
# (800, 2)
# Shape of labels: File name:   (800, 2)491.mp4
#
# File name:  124.mp4
# [Epoch 17/20] [Batch 71 / 119] [Loss: 0.225103, Acc: 95.14%]
# File name:  331.mp4
# Shape of labels:  (800, 2)
# File name:  Shape of labels: 319.mp4
# (800, 2)
# File name:  202.mp4
# Shape of labels:  (800, 2)
# File name:  625.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 72 / 119] [Loss: 0.222606, Acc: 95.21%] 131.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  354.mp4
# (800, 2)
# File name:  358.mp4
# Shape of labels:  (800, 2)
# File name:  418.mp4
# [Epoch 17/20] [Batch 73 / 119] [Loss: 0.220340, Acc: 95.27%] (800, 2)
# File name:  Shape of labels:  76.mp4(800, 2)
#
# File name: Shape of labels:   496.mp4(800, 2)
#
# File name:  618.mp4Shape of labels:
#  (800, 2)
# File name:  145.mp4
# [Epoch 17/20] [Batch 74 / 119] [Loss: 0.218394, Acc: 95.33%]Shape of labels:  (800, 2)
# File name:  411.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:   (800, 2)555.mp4
#
# File name: Shape of labels:   (800, 2)308.mp4
#
# [Epoch 17/20] [Batch 75 / 119] [Loss: 0.220132, Acc: 95.39%]
# Shape of labels:  Shape of labels: (800, 2)
#  File name:  (800, 2)83.mp4
#
# File name:  Shape of labels: 303.mp4
# (800, 2)
# File name: Shape of labels:   524.mp4(800, 2)
#
# [Epoch 17/20] [Batch 77 / 119] [Loss: 0.216994, Acc: 95.51%]
#  (800, 2)
# Shape of labels:  File name:  (800, 2)
# 158.mp4
# File name:  182.mp4Shape of labels:
#  (800, 2)Shape of labels:
#  File name: (800, 2)
# 530.mp4File name:
#  272.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:   (800, 2)315.mp4
#
# File name:  Shape of labels: 107.mp4
# (800, 2)
# File name: Shape of labels:   53.mp4(800, 2)
#
# File name:  239.mp4
# [Epoch 17/20] [Batch 79 / 119] [Loss: 0.218009, Acc: 95.62%](800, 2)
# File name:  536.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
#  134.mp4
# File name:  611.mp4
# Shape of labels:  (800, 2)
# File name:  109.mp4
# Shape of labels:  (800, 2)
# File name:  490.mp4
# Shape of labels:  Shape of labels: (800, 2)
#  File name: (800, 2)
# 335.mp4File name:
#  329.mp4
# Shape of labels:  (800, 2)
# File name:  372.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 80 / 119] [Loss: 0.217720, Acc: 95.68%] 586.mp4
# Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# File name:  336.mp4
# 323.mp4
# Shape of labels:  (800, 2)
# File name:  224.mp4
# [Epoch 17/20] [Batch 81 / 119] [Loss: 0.219518, Acc: 95.73%]Shape of labels:  (800, 2)Shape of labels:
# (800, 2)
# File name: File name:  117.mp4
#  553.mp4
# Shape of labels:  Shape of labels: (800, 2)
# File name:  259.mp4
#  (800, 2)
# File name:  245.mp4
# [Epoch 17/20] [Batch 82 / 119] [Loss: 0.220120, Acc: 95.78%](800, 2)
# File name:  217.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 274.mp4
# 213.mp4
# Shape of labels:  (800, 2)
# File name:  294.mp4
# [Epoch 17/20] [Batch 83 / 119] [Loss: 0.219646, Acc: 95.83%]Shape of labels:  Shape of labels: (800, 2)
# (800, 2)
# File name:  479.mp4File name:
#  Shape of labels: 560.mp4
#  Shape of labels:  (800, 2)
# File name:  28.mp4
# (800, 2)
# File name:  141.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 84 / 119] [Loss: 0.220290, Acc: 95.88%] 266.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
# File name:   500.mp4537.mp4
#
# Shape of labels:  (800, 2)
# File name:  126.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 85 / 119] [Loss: 0.221809, Acc: 95.93%] 626.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 534.mp4
#  100.mp4
# Shape of labels:  (800, 2)
# File name:  47.mp4
# [Epoch 17/20] [Batch 86 / 119] [Loss: 0.220666, Acc: 95.98%](800, 2)
# File name: Shape of labels:   568.mp4(800, 2)
#
# File name: Shape of labels:   132.mp4
# (800, 2)
# File name: Shape of labels:  368.mp4 (800, 2)
#
# File name:  599.mp4
# [Epoch 17/20] [Batch 87 / 119] [Loss: 0.218949, Acc: 96.02%]
# File name:  Shape of labels:  (800, 2)542.mp4
# File name:
#  194.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   248.mp4155.mp4
#
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 88 / 119] [Loss: 0.218760, Acc: 96.07%]
# Shape of labels:  Shape of labels: (800, 2)
# File name: (800, 2)
# 16.mp4
# File name:  573.mp4
# Shape of labels:  (800, 2)
# File name:  391.mp4
# [Epoch 17/20] [Batch 89 / 119] [Loss: 0.218318, Acc: 96.11%]Shape of labels:  (800, 2)
# Shape of labels: File name:  (800, 2) 37.mp4
#
# File name:  547.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
# File name: 370.mp4
# 627.mp4
# [Epoch 17/20] [Batch 90 / 119] [Loss: 0.220066, Acc: 96.15%]Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 161.mp4
# 143.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   352.mp4533.mp4
#
# [Epoch 17/20] [Batch 91 / 119] [Loss: 0.218019, Acc: 96.20%]
# File name:  168.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
# File name:  345.mp4File name:
#
#  285.mp4
# Shape of labels:  (800, 2)
# File name:  57.mp4
# [Epoch 17/20] [Batch 92 / 119] [Loss: 0.217052, Acc: 96.24%]Shape of labels:  (800, 2)
# File name:  31.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name:  File name: 298.mp4 313.mp4
#
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 93 / 119] [Loss: 0.216636, Acc: 96.28%]
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
# File name:
# File name: 588.mp4
#  480.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
# File name:  304.mp4
#
# [Epoch 17/20] [Batch 94 / 119] [Loss: 0.217542, Acc: 96.05%]File name:  (800, 2)
# File name:  623.mp4
# 30.mp4Shape of labels:  (800, 2)Shape of labels:
# File name:
#  (800, 2)98.mp4
#
# File name:  407.mp4
# Shape of labels:  (800, 2)
# File name:  159.mp4
# [Epoch 17/20] [Batch 95 / 119] [Loss: 0.215668, Acc: 96.09%]Shape of labels:  (800, 2)
# File name:  591.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   (800, 2)254.mp4
#
# File name:  283.mp4
# Shape of labels:  (800, 2)
# File name:  310.mp4
# [Epoch 17/20] [Batch 96 / 119] [Loss: 0.214132, Acc: 96.13%]Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
#  File name: 69.mp4
#  620.mp4Shape of labels:
#  (800, 2)
# File name:  Shape of labels:  152.mp4(800, 2)
#
# File name:  84.mp4
# [Epoch 17/20] [Batch 97 / 119] [Loss: 0.213145, Acc: 96.17%]Shape of labels:  (800, 2)
# File name:  Shape of labels: 481.mp4
# (800, 2)
# File name: Shape of labels:   408.mp4(800, 2)
#
# File name:  506.mp4
# Shape of labels:  (800, 2)
# [Epoch 17/20] [Batch 98 / 119] [Loss: 0.213209, Acc: 96.21%]
# Shape of labels:  (800, 2)
# File name:  333.mp4Shape of labels:  (800, 2)
# File name:  520.mp4
#
# Shape of labels: Shape of labels:  (800, 2)
# File name:  218.mp4
#  (800, 2)
# File name:  484.mp4
# [Epoch 17/20] [Batch 99 / 119] [Loss: 0.211301, Acc: 96.25%]Shape of labels:  (800, 2)
# File name:  12.mp4
# Shape of labels: Shape of labels:  (800, 2)
# (800, 2)
# File name: File name:  97.mp4
#  614.mp4Shape of labels:
#  (800, 2)
# File name:  402.mp4
# [Epoch 17/20] [Batch 100 / 119] [Loss: 0.209633, Acc: 96.29%]Shape of labels:  (800, 2)
# Shape of labels:  (800, 2)
# File name:  289.mp4
# File name:  287.mp4
# Shape of labels:  (800, 2)
# File name:  172.mp4
# Shape of labels: Shape of labels:   (800, 2)
#  File name: 565.mp4
# (800, 2)
# [Epoch 17/20] [Batch 101 / 119] [Loss: 0.209497, Acc: 96.08%]
# Shape of labels:  (800, 2)
# File name:  192.mp4
# Shape of labels:  (800, 2)
# File name:  377.mp4
# Shape of labels:  (800, 2)
# File name:  566.mp4
# Shape of labels:  (800, 2)
# File name:  216.mp4
# [Epoch 17/20] [Batch 102 / 119] [Loss: 0.209259, Acc: 96.12%] (800, 2)
# File name:  617.mp4
# Shape of labels:  (800, 2)
# File name:  156.mp4
# Shape of labels:  (800, 2)
# File name:  142.mp4
# [Epoch 17/20] [Batch 103 / 119] [Loss: 0.211491, Acc: 96.15%]Shape of labels:  (800, 2)
# File name:  612.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  416.mp4
# (800, 2)
# File name:  40.mp4
# Shape of labels:  (800, 2)
# File name:  395.mp4
# [Epoch 17/20] [Batch 104 / 119] [Loss: 0.209869, Acc: 96.19%]Shape of labels:  (800, 2)
# Shape of labels: File name:   (800, 2)
# 128.mp4
# File name:  357.mp4Shape of labels:
# Shape of labels: (800, 2) (800, 2)
# File name:
#  File name:  284.mp4
# 7.mp4
# [Epoch 17/20] [Batch 105 / 119] [Loss: 0.211747, Acc: 96.23%]Shape of labels: Shape of labels:   (800, 2)
# File name:  364.mp4
# (800, 2)
# File name:  369.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# File name: (800, 2)
#  173.mp4
# [Epoch 17/20] [Batch 106 / 119] [Loss: 0.211573, Acc: 96.26%] Shape of labels: 59.mp4
# Shape of labels:  (800, 2)(800, 2)
# File name:  157.mp4
#
# File name:  502.mp4Shape of labels:
# (800, 2)
# File name:  Shape of labels: 325.mp4
#  (800, 2)Shape of labels:
#  File name:  204.mp4
# [Epoch 17/20] [Batch 107 / 119] [Loss: 0.210032, Acc: 96.30%]
# File name:  94.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
# File name: 184.mp4
#  317.mp4
# Shape of labels:  (800, 2)
# File name:  476.mp4
# [Epoch 17/20] [Batch 108 / 119] [Loss: 0.208269, Acc: 96.33%]Shape of labels:  (800, 2)
# File name:  584.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  545.mp4
#  (800, 2)
# File name:  185.mp4
# Shape of labels:  (800, 2)
# File name:  518.mp4
# Shape of labels:  (800, 2)
# File name:  589.mp4
# [Epoch 17/20] [Batch 118 / 119] [Loss: 0.231907, Acc: 95.79%]Testing
# Shape of labels: Shape of labels:   Shape of labels: (800, 2)(800, 2)
#
# (800, 2)File name: File name: Shape of labels:
#  595.mp4  File name:
# (800, 2)200.mp4
#
# 603.mp4File name:
#  442.mp4
# Shape of labels:  (800, 2)
# File name:  129.mp4Shape of labels:  (800, 2)
# File name: Shape of labels:
#   (800, 2)
# 430.mp4File name:  Shape of labels: 462.mp4
#
#  (800, 2)Shape of labels:
# File name:   390.mp4
# Shape of labels: (800, 2)Shape of labels:
#  (800, 2)File name: (800, 2)
# 601.mp4File name:
#
# 326.mp4File name: Shape of labels:
#  (800, 2)376.mp4
#
# File name:  628.mp4
# Shape of labels:  (800, 2)
# Shape of labels: Shape of labels:   (800, 2)File name: Shape of labels:
# (800, 2) File name: 23.mp4
#
#  (800, 2)File name: 264.mp4
# 432.mp4
#
# File name:  Shape of labels: Shape of labels: 635.mp4
# (800, 2)(800, 2)
#
# File name: File name:   640.mp4634.mp4
#
# Shape of labels: Shape of labels:   Shape of labels: (800, 2)(800, 2)Shape of labels:
#
# (800, 2)(800, 2)File name:
# File name: File name:
#  File name:  11.mp4583.mp4
# 265.mp4608.mp4
#
#
# Shape of labels: Shape of labels:   Shape of labels: Shape of labels: (800, 2)(800, 2)  (800, 2)
#
#
# (800, 2)
# File name: File name: File name:   166.mp4File name:  373.mp4
#
# 24.mp4
# [Batch 1 / 37]  [Loss: 0.158003, Acc: 100.00%]
# Shape of labels: Shape of labels: Shape of labels: Shape of labels:   (800, 2) (800, 2)
# (800, 2)(800, 2)
#
# File name:
# File name:  File name: File name:  461.mp4  509.mp4
# 607.mp4454.mp4
#
#
# Shape of labels:  (800, 2)
# [Batch 3 / 37]  [Loss: 0.602684, Acc: 87.50%]Shape of labels: 453.mp4Shape of labels:
#  (800, 2)
# File name:  463.mp4
# (800, 2)(800, 2)
#
# File name: File name:  Shape of labels:  208.mp4 (800, 2)
# 19.mp4
# File name:
# Shape of labels:  256.mp4 Shape of labels:
# (800, 2)
# File name:   Shape of labels: (800, 2)434.mp4
#  Shape of labels:
# File name: (800, 2)
# (800, 2)
# 386.mp4File name:
# Shape of labels: File name:    457.mp4247.mp4
# [Batch 5 / 37]  [Loss: 1.013892, Acc: 79.17%](800, 2)
# Shape of labels: Shape of labels: Shape of labels:
#   File name:  (800, 2) (800, 2)(800, 2)255.mp4
#
#
# File name: File name:
# File name:  295.mp4  459.mp4474.mp4
# Shape of labels:
#
#  Shape of labels: Shape of labels: (800, 2)Shape of labels:
#    (800, 2)File name: (800, 2)(800, 2)
#
#
# File name: File name: 62.mp4File name:
#    428.mp4633.mp4433.mp4
#
#
# [Batch 7 / 37]  [Loss: 0.781029, Acc: 84.38%]Shape of labels: Shape of labels:  (800, 2)Shape of labels:
# Shape of labels:  File name: (800, 2)
# File name:    (800, 2) 138.mp4
# (800, 2)638.mp4
#
# File name:
# File name: Shape of labels:   642.mp466.mp4
#
#  Shape of labels: (800, 2)
# Shape of labels: Shape of labels: (800, 2)
# File name:  File name: (800, 2)
# (800, 2)
# File name:  450.mp4
# 237.mp4File name: 383.mp4
# 447.mp4
#
# Shape of labels: Shape of labels:   (800, 2)(800, 2)Shape of labels:
#
#  File name: File name: (800, 2)
# File name: 471.mp4253.mp4
#
# 531.mp4
# [Batch 9 / 37]  [Loss: 0.640927, Acc: 87.50%] (800, 2)Shape of labels: Shape of labels: Shape of labels:
#    File name: (800, 2)(800, 2) (800, 2)
#
#
# 93.mp4File name: File name: File name:
# 446.mp4
#    460.mp4
# 449.mp4Shape of labels:
# Shape of labels:   (800, 2)(800, 2)
# Shape of labels:
# File name:  File name:  (800, 2) 355.mp4
# 21.mp4
# File name:
# [Batch 11 / 37]  [Loss: 0.866839, Acc: 79.17%](800, 2)219.mp4
#
# Shape of labels:  File name: (800, 2) 385.mp4Shape of labels:
# File name:  643.mp4
#  Shape of labels:  (800, 2)(800, 2)
#
# File name:
# Shape of labels: File name:  Shape of labels: 359.mp4
#  81.mp4 (800, 2)
# (800, 2)
# File name:
#   Shape of labels: File name: 45.mp4(800, 2)374.mp4
#
#
# Shape of labels: Shape of labels: File name:   (800, 2)
#  (800, 2)
# File name: Shape of labels: File name: 35.mp4
#    469.mp4(800, 2)384.mp4
#  File name:
# [Batch 13 / 37]  [Loss: 0.853365, Acc: 78.57%]
# 639.mp4
# Shape of labels: Shape of labels:   File name: (800, 2)(800, 2)
#
# File name:   429.mp4371.mp4Shape of labels:
# Shape of labels:
#  (800, 2)(800, 2)
#
# File name: Shape of labels: File name:   401.mp4 (800, 2)Shape of labels: 452.mp4
#
#
# File name: (800, 2)
# File name: 473.mp4
# Shape of labels:  153.mp4Shape of labels:
#
# [Batch 15 / 37]  [Loss: 1.211262, Acc: 73.44%] (800, 2)(800, 2)Shape of labels:
# File name: File name:    Shape of labels: 451.mp4300.mp4(800, 2)
#
#
# (800, 2)
# File name: File name:   Shape of labels: Shape of labels: 238.mp4258.mp4
#   (800, 2)
# (800, 2)
#
# File name: File name:   347.mp4235.mp4
#
# Shape of labels:  Shape of labels: (800, 2)
# Shape of labels: File name: (800, 2)
# (800, 2)File name: 458.mp4
#
#  Shape of labels: File name:  278.mp4 576.mp4
# (800, 2)
# [Batch 17 / 37]  [Loss: 1.303992, Acc: 70.83%]
# Shape of labels: File name:  Shape of labels:  (800, 2)Shape of labels:  445.mp4
#
# (800, 2)(800, 2)File name:
#
# File name:  26.mp4File name:   Shape of labels: 299.mp4
#  (800, 2)282.mp4
#
#
# File name: Shape of labels:   (800, 2)443.mp4
#
# File name:  Shape of labels: 178.mp4Shape of labels:
#  (800, 2)(800, 2)
# Shape of labels:
# File name:  File name: Shape of labels:  (800, 2)
#  File name: 436.mp4 590.mp4
#  427.mp4(800, 2)
#
#
# [Batch 19 / 37]  [Loss: 1.247890, Acc: 72.50%]Shape of labels: File name:  (800, 2)
# 38.mp4
# File name: Shape of labels: Shape of labels:   Shape of labels: (800, 2)  456.mp4
# (800, 2)File name:
# (800, 2) File name:
# 435.mp4
#
# 50.mp4Shape of labels: File name:
# Shape of labels:    (800, 2)(800, 2)
# 472.mp4File name:
#
# File name:  Shape of labels: 89.mp4
# 18.mp4 (800, 2)
# Shape of labels: Shape of labels:  File name:
#  (800, 2)
# [Batch 21 / 37]  [Loss: 1.173982, Acc: 73.86%]File name:  455.mp4
#  (800, 2)Shape of labels:  (800, 2)File name:
# 470.mp4
# Shape of labels:
# (800, 2) File name:
# Shape of labels: 439.mp4  438.mp4
# File name:
# (800, 2)
# 120.mp4File name:
# 466.mp4Shape of labels: Shape of labels:
# (800, 2)(800, 2)
# File name:  637.mp4
#
# [Batch 23 / 37]  [Loss: 1.161776, Acc: 72.92%] Shape of labels: Shape of labels:   (800, 2)467.mp4(800, 2)Shape of labels:
#
#
#  (800, 2)File name: File name:
#  Shape of labels: 440.mp4
# File name:   468.mp4 165.mp4
# (800, 2)
#
# Shape of labels:  (800, 2)File name:  636.mp4
#
# Shape of labels: Shape of labels: File name:    Shape of labels:  (800, 2)641.mp4
# (800, 2)(800, 2)
# File name:
#
#  570.mp4
# File name: Shape of labels:
# [Batch 25 / 37]  [Loss: 1.136966, Acc: 73.08%] Shape of labels:
# 444.mp4431.mp4
#
#  (800, 2)
#
# File name:  170.mp4Shape of labels: Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:  242.mp4
#  Shape of labels:
# File name:  (800, 2) Shape of labels: 228.mp4(800, 2)
#
#
# [Batch 27 / 37]  [Loss: 1.181112, Acc: 71.43%]464.mp4
#  File name: 179.mp4
#
#  File name:
# 437.mp4
# 441.mp4
# Shape of labels:  Shape of labels: Shape of labels: (800, 2)  (800, 2)(800, 2)
#
#
# Shape of labels:  (800, 2)
# File name: File name: File name:   122.mp4File name:
#  631.mp4188.mp4
#  630.mp4
# Shape of labels: Shape of labels:
# Shape of labels: (800, 2)(800, 2)
#
# File name: Shape of labels: File name: (800, 2)
# [Batch 29 / 37]  [Loss: 1.116841, Acc: 72.50%] (800, 2)File name:
# 629.mp4
# File name:
# 51.mp4448.mp4
# Shape of labels:  (800, 2)632.mp4File name:
#
# Shape of labels:  (800, 2)
# 212.mp4
# Shape of labels: Shape of labels: File name:    (800, 2)(800, 2)Shape of labels: 343.mp4
#
#
# File name: File name: (800, 2)  305.mp4512.mp4
# File name:
# [Batch 32 / 37]  [Loss: 1.033090, Acc: 74.24%]
#  465.mp4Shape of labels:
#  (800, 2)
# File name:  42.mp4
# Shape of labels:  (800, 2)
# File name:  193.mp4
# [Batch 36 / 37]  [Loss: 0.949242, Acc: 76.55%]
# Accuracy 76.55172413793103
# Shape of labels: Shape of labels:  Shape of labels:   (800, 2)(800, 2)Shape of labels:
# (800, 2)
#
# File name: (800, 2)File name: File name:
#  517.mp4320.mp4
#
# 33.mp4File name:
#  257.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  294.mp4
# (800, 2)
# Shape of labels: File name:   (800, 2)618.mp4
#
# Shape of labels: Shape of labels:   File name: (800, 2)(800, 2)
#
# 55.mp4Shape of labels:
# File name: File name:   (800, 2) 556.mp4
#
# 369.mp4File name:
# Shape of labels:  218.mp4 Shape of labels: (800, 2)
#
# (800, 2)Shape of labels: File name:
#  File name:  (800, 2)
# Shape of labels: 588.mp4File name: 335.mp4
#
# (800, 2)
# File name:  267.mp4311.mp4
# Shape of labels:
# Shape of labels: Shape of labels:  (800, 2)
# File name:  380.mp4
#  (800, 2)
#  (800, 2)File name:
# Shape of labels: Shape of labels:  249.mp4
# File name:   574.mp4
#  (800, 2)(800, 2)
#
# File name:  File name:  358.mp4304.mp4
# Shape of labels:
#  Shape of labels:  (800, 2)Shape of labels: Shape of labels:
#  (800, 2) File name:
# (800, 2)
# (800, 2)
# File name:   532.mp4File name: File name:
# 414.mp4 538.mp4 567.mp4
#
#
# Shape of labels:  (800, 2)
# File name:  263.mp4
# Shape of labels: Shape of labels: Shape of labels:   (800, 2)
# File name:   (800, 2)Shape of labels: 47.mp4
#
# File name: (800, 2)  (800, 2)
#
#  File name: Shape of labels:  (800, 2)
# 217.mp4172.mp4File name:
#
# File name:  111.mp4
#  Shape of labels: 382.mp4Shape of labels:
#  (800, 2)
# File name:  100.mp4
# (800, 2)
# File name:  146.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  (800, 2)File name:
#  331.mp4File name:
# 86.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  (800, 2)File name:
# File name:   599.mp4544.mp4
#
# [Epoch 18/20] [Batch 0 / 119] [Loss: 0.193330, Acc: 100.00%]Shape of labels:   (800, 2)(800, 2)
#
# File name: File name: Shape of labels:    279.mp4(800, 2)98.mp4
#
#
# File name:  Shape of labels: Shape of labels: 395.mp4
# (800, 2)(800, 2)
#
# File name: File name: Shape of labels:    104.mp4251.mp4(800, 2)
#
#
# File name: Shape of labels:  95.mp4
# [Epoch 18/20] [Batch 1 / 119] [Loss: 0.283748, Acc: 87.50%]
# File name: Shape of labels:  8.mp4
# (800, 2)
# File name:  554.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   614.mp4426.mp4
#
# Shape of labels:  (800, 2)
# File name:  605.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 2 / 119] [Loss: 0.193467, Acc: 91.67%]
# Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# 410.mp4
# File name:  Shape of labels: 36.mp4
#  (800, 2)
# File name:  16.mp4
# [Epoch 18/20] [Batch 3 / 119] [Loss: 0.361202, Acc: 87.50%]Shape of labels:  Shape of labels:  (800, 2)
# File name: (800, 2)
# 333.mp4
# File name:  Shape of labels: 625.mp4
# (800, 2)
# File name:  46.mp4
# Shape of labels:  (800, 2)Shape of labels:  (800, 2)
# File name:
# [Epoch 18/20] [Batch 4 / 119] [Loss: 0.328239, Acc: 90.00%]475.mp4File name:
#  48.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   248.mp4317.mp4
#
# Shape of labels:  (800, 2)
# File name:  485.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 5 / 119] [Loss: 0.306541, Acc: 91.67%] 296.mp4
# Shape of labels:  (800, 2)
# File name:  559.mp4
# Shape of labels:  Shape of labels: (800, 2)
# File name: (800, 2)
# File name: 407.mp4
#  617.mp4Shape of labels:
# (800, 2)
# File name:  418.mp4
# [Epoch 18/20] [Batch 6 / 119] [Loss: 0.343332, Acc: 89.29%]Shape of labels:  (800, 2)
# File name:  132.mp4
# Shape of labels:  (800, 2)
# File name:  60.mp4
# Shape of labels:  (800, 2)
# File name:  328.mp4
# [Epoch 18/20] [Batch 8 / 119] [Loss: 0.367675, Acc: 88.89%](800, 2)
# File name:
# 65.mp4
# File name:  569.mp4Shape of labels:
# Shape of labels:  (800, 2)
# File name:  14.mp4
#  (800, 2)
# File name:  479.mp4
# Shape of labels:  (800, 2)
# File name:  1.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
# File name:
# File name:   515.mp4424.mp4
#
# Shape of labels:  (800, 2)
# File name:  313.mp4
# Shape of labels:  (800, 2)
# File name:  399.mp4
# [Epoch 18/20] [Batch 9 / 119] [Loss: 0.393945, Acc: 87.50%]Shape of labels:  (800, 2)
# File name:  Shape of labels:  546.mp4(800, 2)
#
# File name:  80.mp4
# Shape of labels:  (800, 2)
# File name:  37.mp4
# [Epoch 18/20] [Batch 11 / 119] [Loss: 0.364513, Acc: 87.50%]Shape of labels: Shape of labels:   (800, 2)
# (800, 2)File name:
# File name:   43.mp4
# 505.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
#
# File name: File name:   363.mp4155.mp4
#
# Shape of labels:  (800, 2)
# File name: Shape of labels:   244.mp4(800, 2)
#
# File name:  Shape of labels: 39.mp4
# (800, 2)
# Shape of labels: File name:   (800, 2)3.mp4
#
# File name:  319.mp4
# [Epoch 18/20] [Batch 12 / 119] [Loss: 0.369744, Acc: 86.54%]Shape of labels:  (800, 2)
# Shape of labels:  File name: (800, 2)
#  File name: 483.mp4
#  585.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# File name:  185.mp4
# (800, 2)
# [Epoch 18/20] [Batch 13 / 119] [Loss: 0.347198, Acc: 87.50%]
# Shape of labels:  (800, 2)
# File name:  221.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name: (800, 2)
# File name: 118.mp4
# 241.mp4Shape of labels:  (800, 2)
# File name:
#  309.mp4
# [Epoch 18/20] [Batch 14 / 119] [Loss: 0.336338, Acc: 88.33%] (800, 2)
# File name:  6.mp4Shape of labels:
#  (800, 2)
# Shape of labels: File name:  (800, 2)
# 419.mp4File name:
#  611.mp4
# Shape of labels:  (800, 2)
# File name:  547.mp4Shape of labels:
# [Epoch 18/20] [Batch 16 / 119] [Loss: 0.327296, Acc: 89.71%] (800, 2)
# Shape of labels:  File name:  405.mp4(800, 2)
#
# File name:  Shape of labels: 352.mp4
# (800, 2)Shape of labels:
# File name: (800, 2)
#  482.mp4File name:
# 261.mp4Shape of labels:
# (800, 2)
# File name:  214.mp4
# Shape of labels:  (800, 2)
# File name:  280.mp4
# Shape of labels:  (800, 2)
# File name:  370.mp4
# Shape of labels:  (800, 2)
# File name:  234.mp4
# Shape of labels:  (800, 2)
# File name:  621.mp4
# [Epoch 18/20] [Batch 17 / 119] [Loss: 0.332449, Acc: 90.28%]Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
#  File name: 175.mp4
#  550.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 18 / 119] [Loss: 0.324501, Acc: 90.79%]
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name:  168.mp4File name:
# 203.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name:  78.mp4
# File name:  22.mp4
# [Epoch 18/20] [Batch 19 / 119] [Loss: 0.310976, Acc: 91.25%] (800, 2)
# File name: Shape of labels:   (800, 2)
# 534.mp4File name:  337.mp4
#
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name: 9.mp4
# 270.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 20 / 119] [Loss: 0.297182, Acc: 91.67%]372.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:  262.mp4(800, 2)
# File name:
# 560.mp4Shape of labels:
#  (800, 2)
# File name:  303.mp4
# [Epoch 18/20] [Batch 21 / 119] [Loss: 0.304520, Acc: 90.91%] (800, 2)
# Shape of labels: File name:  142.mp4
#  (800, 2)Shape of labels:
# File name: (800, 2)
# 7.mp4
# File name:  492.mp4
# Shape of labels:  (800, 2)
# File name:  13.mp4
# [Epoch 18/20] [Batch 22 / 119] [Loss: 0.292572, Acc: 91.30%]Shape of labels:  Shape of labels:  (800, 2)(800, 2)
# File name:
# File name:  79.mp4
# 145.mp4
# Shape of labels:  Shape of labels: (800, 2)
# File name:   (800, 2)41.mp4
# File name:
# [Epoch 18/20] [Batch 23 / 119] [Loss: 0.287813, Acc: 91.67%]591.mp4
# Shape of labels:  (800, 2)
# File name:  114.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  101.mp4
# (800, 2)
# File name:  250.mp4
# Shape of labels:  (800, 2)
# File name:  413.mp4
# [Epoch 18/20] [Batch 24 / 119] [Loss: 0.291451, Acc: 92.00%]Shape of labels:  (800, 2)
# File name:  202.mp4Shape of labels:
#  (800, 2)Shape of labels:
#  (800, 2)
# File name:  308.mp4
# File name:  484.mp4Shape of labels:
#  (800, 2)
# File name:  72.mp4
# [Epoch 18/20] [Batch 25 / 119] [Loss: 0.287723, Acc: 92.31%]Shape of labels:  (800, 2)
# File name:  592.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  557.mp4
# Shape of labels: (800, 2)
#  File name:  (800, 2)229.mp4
#
# File name:  301.mp4
# Shape of labels:  (800, 2)
# File name:  147.mp4
# [Epoch 18/20] [Batch 26 / 119] [Loss: 0.277882, Acc: 92.59%]Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   423.mp4579.mp4
#
# Shape of labels:  (800, 2)
# File name:  516.mp4
# [Epoch 18/20] [Batch 27 / 119] [Loss: 0.268901, Acc: 92.86%](800, 2)
# File name:  Shape of labels: 622.mp4
# (800, 2)
# File name:  75.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# File name:  503.mp4
# (800, 2)
# File name:  325.mp4Shape of labels:
#  (800, 2)
# [Epoch 18/20] [Batch 28 / 119] [Loss: 0.267132, Acc: 93.10%]File name:  231.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
# File name:  623.mp4
#
# File name:  87.mp4Shape of labels:
#  (800, 2)
# File name:  415.mp4
# [Epoch 18/20] [Batch 29 / 119] [Loss: 0.275862, Acc: 93.33%]Shape of labels:  (800, 2)
# File name:  306.mp4
# Shape of labels: Shape of labels:  (800, 2) (800, 2)File name:
#
# File name:   73.mp4
# 619.mp4
# Shape of labels:  (800, 2)
# File name:  510.mp4
# [Epoch 18/20] [Batch 30 / 119] [Loss: 0.273121, Acc: 93.55%]Shape of labels:  Shape of labels: (800, 2) File name:
# (800, 2)
# File name: 220.mp4
# 143.mp4
# Shape of labels:  (800, 2)
# File name:  350.mp4
# Shape of labels:  (800, 2)
# File name:  173.mp4
# [Epoch 18/20] [Batch 31 / 119] [Loss: 0.270796, Acc: 93.75%]Shape of labels:  (800, 2)
# File name: Shape of labels:  281.mp4
#   (800, 2)
# File name: 568.mp4Shape of labels:
#  Shape of labels:  (800, 2)(800, 2)
#  File name: 154.mp4
#
# File name: Shape of labels:  File name: (800, 2)
#   252.mp4
# 578.mp4
# [Epoch 18/20] [Batch 32 / 119] [Loss: 0.268928, Acc: 93.94%](800, 2)
# File name:  17.mp4
# Shape of labels:  (800, 2)
# File name:  290.mp4
# Shape of labels:  (800, 2)
# File name:  124.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 33 / 119] [Loss: 0.262032, Acc: 94.12%]File name:  416.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)
# File name: File name:  573.mp4
# 292.mp4
# Shape of labels:  (800, 2)
# File name:  171.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 34 / 119] [Loss: 0.255275, Acc: 94.29%]File name:  269.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  476.mp4 (800, 2)
#
# File name:  149.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 35 / 119] [Loss: 0.257319, Acc: 94.44%] 553.mp4
# Shape of labels:  (800, 2)
# File name:  615.mp4Shape of labels:
#  Shape of labels: (800, 2) (800, 2)
#
# File name: File name:  158.mp4
#  Shape of labels: 602.mp4
# [Epoch 18/20] [Batch 36 / 119] [Loss: 0.255392, Acc: 94.59%](800, 2)
# Shape of labels: File name: 92.mp4  (800, 2)
#
# Shape of labels: File name:   (800, 2)
# 187.mp4File name:
# 388.mp4
# Shape of labels:  Shape of labels: (800, 2)
#  File name:  233.mp4(800, 2)
#
# [Epoch 18/20] [Batch 37 / 119] [Loss: 0.258605, Acc: 94.74%] 205.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels:   239.mp4
# (800, 2)
# File name: Shape of labels: 314.mp4
#   (800, 2)Shape of labels:
# File name:   (800, 2)340.mp4
#
# File name:  207.mp4
# [Epoch 18/20] [Batch 38 / 119] [Loss: 0.258481, Acc: 94.23%]Shape of labels:  (800, 2)
# File name:  334.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   (800, 2)297.mp4
#
# File name:  69.mp4
# Shape of labels:  (800, 2)
# File name:  345.mp4
# Shape of labels:  (800, 2)
# [Epoch 18/20] [Batch 39 / 119] [Loss: 0.254184, Acc: 94.38%]
# Shape of labels:  (800, 2)
# Shape of labels: File name:  412.mp4
# (800, 2)
# File name:  501.mp4
# Shape of labels:  (800, 2)
# File name:  545.mp4
# [Epoch 18/20] [Batch 40 / 119] [Loss: 0.248442, Acc: 94.51%]Shape of labels:  (800, 2)
# File name:  336.mp4
# Shape of labels:  (800, 2)
# File name:  587.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  105.mp4
# (800, 2)
# File name:  177.mp4
# [Epoch 18/20] [Batch 41 / 119] [Loss: 0.244582, Acc: 94.64%] (800, 2)
# File name:  368.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   276.mp4(800, 2)
#
# File name:  Shape of labels: 391.mp4 (800, 2)
#
# [Epoch 18/20] [Batch 42 / 119] [Loss: 0.239264, Acc: 94.77%]27.mp4
# Shape of labels:  (800, 2)
# File name:  535.mp4
# Shape of labels:  (800, 2)
# File name:  90.mp4Shape of labels:
#  (800, 2)Shape of labels:  (800, 2)
# File name:  137.mp4
#
# File name: Shape of labels:   (800, 2)
# File name:  32.mp4
# 113.mp4
# [Epoch 18/20] [Batch 43 / 119] [Loss: 0.243083, Acc: 94.32%]Shape of labels:  (800, 2)
# File name:  329.mp4
# Shape of labels:  (800, 2)
# File name:  283.mp4
# Shape of labels:  (800, 2)
# File name:  140.mp4
# [Epoch 18/20] [Batch 45 / 119] [Loss: 0.240673, Acc: 94.57%](800, 2)(800, 2)
#
# File name:  File name:  232.mp4
# 116.mp4
# Shape of labels:  Shape of labels: (800, 2)
# (800, 2)File name:
#  File name:  121.mp4
# 582.mp4
# Shape of labels:  Shape of labels:  (800, 2)(800, 2)
#
# File name: File name:   85.mp4
# 77.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# ...
#  File name: 485.mp4
#  150.mp4
# Shape of labels:  (800, 2)
# File name:  285.mp4
# [Epoch 20/20] [Batch 74 / 119] [Loss: 0.263930, Acc: 93.00%]Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   303.mp4236.mp4
#
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   620.mp4261.mp4
#
# [Epoch 20/20] [Batch 75 / 119] [Loss: 0.262957, Acc: 93.09%] (800, 2)
# File name:  249.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name: (800, 2)
# 549.mp4File name:
# 118.mp4
# Shape of labels:  (800, 2)
# File name:  287.mp4
# [Epoch 20/20] [Batch 76 / 119] [Loss: 0.263968, Acc: 92.86%] (800, 2)
# File name:  551.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
# 413.mp4File name:
# 86.mp4
# Shape of labels:  (800, 2)
# File name:  597.mp4
# [Epoch 20/20] [Batch 77 / 119] [Loss: 0.265236, Acc: 92.95%]Shape of labels:  (800, 2)
# File name:  83.mp4
# Shape of labels:  Shape of labels:  (800, 2)
# (800, 2)File name:
#  506.mp4File name:  85.mp4
#
# Shape of labels:  (800, 2)
# File name:  586.mp4
# [Epoch 20/20] [Batch 78 / 119] [Loss: 0.270255, Acc: 92.72%]Shape of labels:  (800, 2)
# File name:  369.mp4
# Shape of labels:  (800, 2)
# File name:  160.mp4
# Shape of labels:  (800, 2)
# File name:  124.mp4
# Shape of labels:  (800, 2)
# File name:  563.mp4
# Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 79 / 119] [Loss: 0.269428, Acc: 92.81%]
# Shape of labels:  (800, 2)
# File name:  4.mp4
# Shape of labels:  Shape of labels: (800, 2) (800, 2)
# File name:
#  266.mp4File name:
# 311.mp4
# [Epoch 20/20] [Batch 80 / 119] [Loss: 0.268257, Acc: 92.90%]Shape of labels:  Shape of labels:  (800, 2)
# (800, 2)
# File name: File name:   533.mp4313.mp4
#
# Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   391.mp4
# 571.mp4
# [Epoch 20/20] [Batch 81 / 119] [Loss: 0.267917, Acc: 92.68%]Shape of labels:  (800, 2)
# File name:  175.mp4
# Shape of labels:  (800, 2)
# File name:  370.mp4
# Shape of labels:  (800, 2)
# File name:  619.mp4
# Shape of labels:  (800, 2)
# File name:  483.mp4
# Shape of labels:  (800, 2)
# File name:  186.mp4
# Shape of labels:  (800, 2)
# File name:  362.mp4
# [Epoch 20/20] [Batch 82 / 119] [Loss: 0.264878, Acc: 92.77%]Shape of labels:  (800, 2)
# File name:  47.mp4
# Shape of labels:  (800, 2)
# File name:  333.mp4
# Shape of labels:  (800, 2)
# File name:  87.mp4
# Shape of labels:  (800, 2)
# File name:  424.mp4
# [Epoch 20/20] [Batch 83 / 119] [Loss: 0.263971, Acc: 92.86%]Shape of labels:  (800, 2)
# File name:  29.mp4
# Shape of labels:  (800, 2)
# File name:  80.mp4
# Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 85 / 119] [Loss: 0.265162, Acc: 93.02%]File name: Shape of labels:   614.mp4(800, 2)
#
# File name:  356.mp4
# Shape of labels: Shape of labels:  (800, 2)
# (800, 2)File name:
# File name: 375.mp4 605.mp4
#
# Shape of labels:  (800, 2)
# File name:  528.mp4
# Shape of labels:  Shape of labels: (800, 2)
# File name:  306.mp4
#  Shape of labels:  (800, 2)
# (800, 2)File name:  419.mp4
#
# File name: Shape of labels:   (800, 2)
# File name:  143.mp4
# 59.mp4
# Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 86 / 119] [Loss: 0.262781, Acc: 93.10%]File name:  511.mp4
# Shape of labels:  (800, 2)
# File name:  98.mp4
# Shape of labels:  (800, 2)
# File name:  316.mp4
# Shape of labels:  (800, 2)
# File name:  155.mp4
# [Epoch 20/20] [Batch 87 / 119] [Loss: 0.259916, Acc: 93.18%]Shape of labels:  (800, 2)
# File name: Shape of labels:   (800, 2)325.mp4
#
# File name:  8.mp4
# Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 89 / 119] [Loss: 0.256641, Acc: 93.33%]592.mp4
# (800, 2)Shape of labels:
# File name:   195.mp4(800, 2)
#
# File name: Shape of labels:  539.mp4
#  (800, 2)Shape of labels:
# (800, 2)
# File name:  216.mp4File name:
#  106.mp4
# Shape of labels:  Shape of labels: (800, 2)
# File name: (800, 2)
#  132.mp4File name:
# 341.mp4Shape of labels:
#  Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 90 / 119] [Loss: 0.255834, Acc: 93.41%]File name: (800, 2) 545.mp4
# File name:  113.mp4
# Shape of labels:  (800, 2)
#
# Shape of labels: File name:   568.mp4(800, 2)
# File name:
#  72.mp4Shape of labels:
#  (800, 2)
# Shape of labels:  File name: (800, 2)
# [Epoch 20/20] [Batch 91 / 119] [Loss: 0.253525, Acc: 93.48%]File name:
# 227.mp4
# Shape of labels:  (800, 2)Shape of labels:
# File name:  577.mp4
# (800, 2)
# File name: Shape of labels:  (800, 2)
# File name:  79.mp4
#  315.mp4
# [Epoch 20/20] [Batch 92 / 119] [Loss: 0.252679, Acc: 93.55%]
# File name:  400.mp4
# Shape of labels:  (800, 2)
# File name:  425.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   (800, 2)100.mp4
# File name:  151.mp4
#
# Shape of labels:  (800, 2)
# File name:  130.mp4
# [Epoch 20/20] [Batch 93 / 119] [Loss: 0.250245, Acc: 93.62%]Shape of labels:  (800, 2)
# File name:  103.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name: (800, 2)
# 32.mp4
# File name:  572.mp4Shape of labels:
# (800, 2)
# File name:  409.mp4
# [Epoch 20/20] [Batch 95 / 119] [Loss: 0.248143, Acc: 93.75%]
# Shape of labels: File name: 513.mp4
#  (800, 2)
# File name:  Shape of labels: 296.mp4 (800, 2)
#
# File name:  49.mp4
# Shape of labels:  (800, 2)
# File name:  494.mp4
# Shape of labels:  (800, 2)
# File name:  360.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name: (800, 2)
# 77.mp4File name:
#  187.mp4
# Shape of labels:  (800, 2)
# File name:  39.mp4
# [Epoch 20/20] [Batch 96 / 119] [Loss: 0.246338, Acc: 93.81%]Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:  538.mp4
# 426.mp4
# Shape of labels:  (800, 2)
# File name:  275.mp4
# Shape of labels:  (800, 2)
# File name:  615.mp4
# [Epoch 20/20] [Batch 97 / 119] [Loss: 0.244376, Acc: 93.88%]Shape of labels:  (800, 2)
# File name:  234.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  516.mp4
#  (800, 2)
# File name:  294.mp4
# Shape of labels:  (800, 2)
# File name:  323.mp4
# Shape of labels:  (800, 2)
# [Epoch 20/20] [Batch 98 / 119] [Loss: 0.245479, Acc: 93.69%]File name:  111.mp4
# Shape of labels: Shape of labels:  (800, 2)
# File name:  476.mp4
#  (800, 2)
# File name:  252.mp4
# Shape of labels:  (800, 2)
# File name:  503.mp4
# Shape of labels:  (800, 2)
# File name:  495.mp4
# [Epoch 20/20] [Batch 99 / 119] [Loss: 0.244838, Acc: 93.75%]Shape of labels:  (800, 2)
# File name:  233.mp4
# Shape of labels:  (800, 2)
# File name:  14.mp4
# Shape of labels:  (800, 2)
# File name:  225.mp4
# [Epoch 20/20] [Batch 101 / 119] [Loss: 0.247145, Acc: 93.87%]Shape of labels:  (800, 2)Shape of labels:
#  File name:  (800, 2)283.mp4
#
# File name:  622.mp4
# Shape of labels:  (800, 2)Shape of labels:
#  File name:  (800, 2)591.mp4
#
# File name:  344.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:  (800, 2)
# 259.mp4File name:
#  336.mp4Shape of labels:
#  (800, 2)Shape of labels:
#  File name: (800, 2)
# 78.mp4
# File name:  379.mp4
# [Epoch 20/20] [Batch 102 / 119] [Loss: 0.246594, Acc: 93.93%]Shape of labels:  (800, 2)Shape of labels:
# (800, 2)File name:
#  File name: 345.mp4
# 95.mp4
# Shape of labels:  (800, 2)
# Shape of labels: File name:   (800, 2)
# 602.mp4File name:
#  257.mp4
# [Epoch 20/20] [Batch 103 / 119] [Loss: 0.244820, Acc: 93.99%]Shape of labels: Shape of labels:   (800, 2)(800, 2)
#
# File name: File name:   297.mp4196.mp4
#
# Shape of labels: Shape of labels:   (800, 2)
# File name:  (800, 2)
# 510.mp4File name:
#  352.mp4
# [Epoch 20/20] [Batch 104 / 119] [Loss: 0.247482, Acc: 94.05%]
# File name:  346.mp4Shape of labels:
#  (800, 2)
# Shape of labels: File name:   (800, 2)408.mp4
# File name:
#  324.mp4Shape of labels:
#  (800, 2)
# File name:  194.mp4
# [Epoch 20/20] [Batch 105 / 119] [Loss: 0.246831, Acc: 94.10%]Shape of labels:  (800, 2)
# File name: Shape of labels:   190.mp4(800, 2)
#
# File name:  202.mp4Shape of labels:
#  Shape of labels: (800, 2)
#  (800, 2)File name:
# File name:   579.mp431.mp4
#
# [Epoch 20/20] [Batch 106 / 119] [Loss: 0.244887, Acc: 94.16%]Shape of labels:  (800, 2)
# File name: Shape of labels:   484.mp4(800, 2)
#
# Shape of labels: File name:   (800, 2)550.mp4
# File name:
#  Shape of labels:  387.mp4(800, 2)
#
# File name:  13.mp4
# [Epoch 20/20] [Batch 107 / 119] [Loss: 0.242873, Acc: 94.21%] Shape of labels: (800, 2)
# File name: (800, 2) 515.mp4
# File name:  125.mp4
#
# Shape of labels:  (800, 2)
# File name:  560.mp4
# Shape of labels: Shape of labels:   (800, 2)
# File name:  498.mp4
# [Epoch 20/20] [Batch 108 / 119] [Loss: 0.242004, Acc: 94.27%](800, 2)
# File name:  197.mp4
#
# File name:  334.mp4
# Shape of labels:  (800, 2)
# File name:  191.mp4
# Shape of labels:  (800, 2)
# File name:  173.mp4
# [Epoch 20/20] [Batch 109 / 119] [Loss: 0.239884, Acc: 94.32%]Shape of labels:  (800, 2)
# File name:  184.mp4
# [Epoch 20/20] [Batch 118 / 119] [Loss: 0.234950, Acc: 94.32%]Testing
# Shape of labels: Shape of labels: Shape of labels:    (800, 2)(800, 2)
#
# (800, 2)File name:  File name:
# Shape of labels: 466.mp4  (800, 2)
#
# File name:  468.mp4188.mp4File name:
#
#  62.mp4
# Shape of labels:  (800, 2)
# File name:   Shape of labels: Shape of labels: Shape of labels:  (800, 2)178.mp4
# File name:  386.mp4
# (800, 2)
#
# (800, 2)File name:
#  Shape of labels: File name: 607.mp4 Shape of labels: (800, 2)
#
# File name:   437.mp4(800, 2)631.mp4
#
#
# File name: Shape of labels:   (800, 2)
# File name:  610.mp4
# 576.mp4Shape of labels: Shape of labels:
#  Shape of labels: (800, 2)File name:
# File name: (800, 2)
#   247.mp4
#  456.mp4
# (800, 2)Shape of labels:
# Shape of labels: File name: (800, 2)
# Shape of labels: File name:  (800, 2)  (800, 2)629.mp4
#
# File name: 601.mp4
# File name:
#   429.mp4458.mp4
#
# Shape of labels: Shape of labels:  Shape of labels:  (800, 2)
# (800, 2)(800, 2)File name:
#
#  File name: 461.mp4File name:
#  442.mp4Shape of labels: 170.mp4
#
#  (800, 2)
# File name:  Shape of labels: 371.mp4Shape of labels:  (800, 2)Shape of labels:
# (800, 2)
# File name:  457.mp4
#
# File name:  Shape of labels:  (800, 2)Shape of labels:   81.mp4(800, 2)
# (800, 2)
#
#
# File name:  File name: File name:  258.mp4
# Shape of labels:   (800, 2)35.mp489.mp4Shape of labels:
#
#
# File name: (800, 2)
# File name:
# [Batch 1 / 37]  [Loss: 0.076866, Acc: 100.00%]Shape of labels:
#
# File name:  11.mp4
# (800, 2)
# File name: Shape of labels:  432.mp4
# Shape of labels: Shape of labels:   (800, 2)(800, 2) (800, 2)
# File name:
#  265.mp4
#
# File name: File name: Shape of labels:    401.mp4
# 256.mp4(800, 2)
# [Batch 3 / 37]  [Loss: 0.331288, Acc: 93.75%]
# (800, 2)Shape of labels: File name:
#  (800, 2)473.mp4
#
# File name: File name:  373.mp4
#  Shape of labels: 472.mp4Shape of labels:
#  (800, 2)  Shape of labels: (800, 2)
# (800, 2)File name:  451.mp4
#
#
# File name:  474.mp4File name:
# Shape of labels:  Shape of labels: 208.mp4
# (800, 2)(800, 2)Shape of labels:
# File name:
#  File name:  452.mp4
# [Batch 5 / 37]  [Loss: 0.596732, Acc: 87.50%] 18.mp4
# (800, 2)(800, 2)
# File name:
#  642.mp4
# Shape of labels: File name: Shape of labels:    (800, 2)235.mp4Shape of labels: (800, 2)
#
# (800, 2)
#
# File name:
# File name:  24.mp4
# 122.mp4 Shape of labels: Shape of labels: File name:   (800, 2) (800, 2)Shape of labels: 436.mp4
#
#
# (800, 2)File name:  299.mp4
#
# [Batch 7 / 37]  [Loss: 0.759904, Acc: 84.38%] 427.mp4 464.mp4
# Shape of labels:
# Shape of labels:  (800, 2)
# File name:  278.mp4
#  Shape of labels: Shape of labels:  (800, 2)(800, 2)
# File name:
# (800, 2)File name:  390.mp4
# File name:  462.mp4443.mp4
# Shape of labels:
#
# Shape of labels: (800, 2)
# Shape of labels: File name:    (800, 2)
# 447.mp4File name:  (800, 2)Shape of labels: 253.mp4
#
#
# 445.mp4File name:   (800, 2)
#
# File name: Shape of labels: Shape of labels:   439.mp4
# [Batch 9 / 37]  [Loss: 0.811702, Acc: 80.00%]
# Shape of labels: File name:   Shape of labels: 449.mp4 (800, 2)(800, 2)
#
#
# (800, 2)File name:  Shape of labels: 212.mp4
#
# File name: (800, 2)File name:
#   326.mp4Shape of labels:
#  26.mp4(800, 2)File name:
#
# Shape of labels:  File name: 255.mp4
#  (800, 2)Shape of labels:
# 440.mp4
# File name: (800, 2) 470.mp4
# [Batch 11 / 37]  [Loss: 0.940949, Acc: 77.08%]  (800, 2)238.mp4
#
# File name:
#  435.mp4
# Shape of labels: (800, 2)
# (800, 2)File name:
# Shape of labels:  File name: 264.mp4
#  179.mp4(800, 2)Shape of labels:
#
# File name:   66.mp4(800, 2)
# Shape of labels:  (800, 2)Shape of labels:
# File name:
#  438.mp4
# Shape of labels:  (800, 2)File name:
#   File name: 641.mp4(800, 2)
#
# Shape of labels: 634.mp4File name:
#   471.mp4(800, 2)
#
# [Batch 13 / 37]  [Loss: 0.854884, Acc: 78.57%]Shape of labels: File name:  (800, 2)Shape of labels:
# File name:   Shape of labels: 639.mp4(800, 2)
#  643.mp4
#
#  (800, 2)Shape of labels:
# File name: File name:  (800, 2)
# File name:   237.mp4 444.mp4
# 583.mp4
# Shape of labels:  Shape of labels:
# Shape of labels: (800, 2)(800, 2)
# File name:  570.mp4
#  (800, 2)
#
# File name: 635.mp4
# [Batch 15 / 37]  [Loss: 0.753063, Acc: 81.25%]File name: Shape of labels:   (800, 2)343.mp4
#
# Shape of labels: File name:  Shape of labels:  (800, 2) (800, 2)Shape of labels: 374.mp4
#
#
# File name: File name:  228.mp4(800, 2)
#
# Shape of labels: 219.mp4File name:   (800, 2)19.mp4
#
#
# File name:  Shape of labels: 632.mp4
# Shape of labels: (800, 2)Shape of labels:  Shape of labels:
# File name:  428.mp4(800, 2)
# File name: (800, 2) 637.mp4
# [Batch 17 / 37]  [Loss: 0.785013, Acc: 80.56%]
#
# (800, 2)File name: Shape of labels:  (800, 2)
# File name:  383.mp4
# 193.mp4
#  File name: Shape of labels: Shape of labels:
#  (800, 2)
#  603.mp4
#  File name:  Shape of labels: (800, 2)165.mp4 Shape of labels:
#
# File name:
#  (800, 2)633.mp4
# (800, 2)
# File name: File name: Shape of labels:  Shape of labels: 608.mp4
# (800, 2)
# (800, 2)
# File name: 636.mp4File name:
# Shape of labels:  (800, 2)
# File name:  38.mp4
# [Batch 19 / 37]  [Loss: 0.826394, Acc: 78.75%]459.mp4Shape of labels:
#
#  Shape of labels: (800, 2)
# File name:   (800, 2)Shape of labels: Shape of labels: 376.mp4
#
# File name: (800, 2)(800, 2)
#  File name: 21.mp4
#
# File name:  531.mp4
# 644.mp4Shape of labels:
# (800, 2)Shape of labels:
#  File name: (800, 2)Shape of labels:  430.mp4Shape of labels:
#   File name: 166.mp4(800, 2)File name:
#
#
#  384.mp4(800, 2)
#
# Shape of labels: Shape of labels:  File name: (800, 2)
# Shape of labels: File name:   (800, 2)(800, 2)
#
#
# 153.mp4
# [Batch 21 / 37]  [Loss: 0.772759, Acc: 79.55%] Shape of labels: File name: 454.mp4Shape of labels:   (800, 2) 455.mp4
# File name:
#
# (800, 2)
# 300.mp4
# File name: Shape of labels: Shape of labels:    (800, 2)460.mp4(800, 2)
# File name:  434.mp4
# Shape of labels:
#
# File name:  467.mp4
#  Shape of labels: (800, 2)
# File name: Shape of labels:   446.mp4
#  Shape of labels:  (800, 2)
# File name:  (800, 2)200.mp4
#
# [Batch 23 / 37]  [Loss: 0.734396, Acc: 79.17%]File name:  50.mp4
# (800, 2)Shape of labels:
# File name: Shape of labels:
#  463.mp4(800, 2)
#  File name: Shape of labels:  93.mp4 (800, 2)
# (800, 2)
# File name:  Shape of labels: 295.mp4
#  (800, 2)
# File name:
# File name:  433.mp4
# Shape of labels:  (800, 2)
# Shape of labels: 431.mp4File name:
#   441.mp4(800, 2)Shape of labels:
# File name:
# Shape of labels:  (800, 2)
# File name:  129.mp4
#  (800, 2)
# [Batch 25 / 37]  [Loss: 0.799974, Acc: 77.88%] 305.mp4448.mp4
#
# Shape of labels: Shape of labels:   Shape of labels:  (800, 2)(800, 2)(800, 2)
# File name:
# Shape of labels:
#  File name: File name:  595.mp4
#  512.mp4
# (800, 2)347.mp4
# File name:
# [Batch 27 / 37]  [Loss: 0.752497, Acc: 79.46%]
#  Shape of labels: (800, 2)Shape of labels:
# (800, 2) File name: (800, 2)
#
# File name:  File name: Shape of labels: 282.mp4628.mp4
#
#
# 138.mp4(800, 2)
# File name:  590.mp4
# Shape of labels: Shape of labels:  Shape of labels: Shape of labels:    (800, 2)(800, 2)(800, 2)
#
# (800, 2)File name:
# File name: File name:
#   469.mp4242.mp4
# File name: 51.mp4
#
#  42.mp4
# Shape of labels:  Shape of labels: (800, 2)Shape of labels:  Shape of labels: (800, 2)
#
# [Batch 29 / 37]  [Loss: 0.729473, Acc: 79.17%]
#
#
#  File name: File name:  45.mp4453.mp4
#
# 630.mp4
# Shape of labels:  (800, 2)
# File name: Shape of labels: Shape of labels:    385.mp4(800, 2)(800, 2)
#
#
# File name: File name:   638.mp423.mp4
#
# [Batch 31 / 37]  [Loss: 0.694147, Acc: 80.47%]Shape of labels:  (800, 2)
# File name:  120.mp4
# [Batch 36 / 37]  [Loss: 0.652110, Acc: 81.38%]
# Accuracy 81.37931034482759
# 20
# Overall accuracy: 0.8137931034482758
# [[68 10]
#  [17 50]]
# True positive =  68
# False positive =  10
# False negative =  17
# True negative =  50
# Calculated Accuracy 81.37931034482759
